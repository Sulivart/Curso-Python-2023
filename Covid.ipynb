# %% [markdown]
# <a href="https://colab.research.google.com/github/Sulivart/Curso-Python-2023/blob/main/Covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=8fde952c51aa335e9065e547072d85abaa8cc29f7eec181a89387356a2d8966a
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import wget

# %%
url='https://datosabiertos.salud.gob.mx/gobmx/salud/datos_abiertos/datos_abiertos_covid19.zip'
wget.download(url)
# Out:
# 'datos_abiertos_covid19.zip'

# %%
# !pip install zipfile-deflate64
# Out:
# Collecting zipfile-deflate64
#   Downloading zipfile_deflate64-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: zipfile-deflate64
# Successfully installed zipfile-deflate64-0.2.0

# %%
import zipfile_deflate64 as zipfile

# %%
zf = zipfile.ZipFile('/content/datos_abiertos_covid19.zip')

# %%
type(zf)
# Out:
# zipfile.ZipFile

# %%
zf.namelist()
# Out:
# ['COVID19MEXICO.csv']

# %%
import pandas as pd

# %%
file = zf.open('COVID19MEXICO.csv')
df = pd.read_csv(file)

# %%
# Tupla: (# de registros, # de columnas)
df.shape
# Out:
# (996403, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996403 entries, 0 to 996402
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   FECHA_ACTUALIZACION    996403 non-null  object
#  1   ID_REGISTRO            996403 non-null  object
#  2   ORIGEN                 996403 non-null  int64
#  3   SECTOR                 996403 non-null  int64
#  4   ENTIDAD_UM             996403 non-null  int64
#  5   SEXO                   996403 non-null  int64
#  6   ENTIDAD_NAC            996403 non-null  int64
#  7   ENTIDAD_RES            996403 non-null  int64
#  8   MUNICIPIO_RES          996403 non-null  int64
#  9   TIPO_PACIENTE          996403 non-null  int64
#  10  FECHA_INGRESO          996403 non-null  object
#  11  FECHA_SINTOMAS         996403 non-null  object
#  12  FECHA_DEF              996403 non-null  object
#  13  INTUBADO               996403 non-null  int64
#  14  NEUMONIA               996403 non-null  int64
#  15  EDAD                   996403 non-null  int64
#  16  NACIONALIDAD           996403 non-null  int64
#  17  EMBARAZO               996403 non-null  int64
#  18  HABLA_LENGUA_INDIG     996403 non-null  int64
#  19  INDIGENA               996403 non-null  int64
#  20  DIABETES               996403 non-null  int64
#  21  EPOC                   996403 non-null  int64
#  22  ASMA                   996403 non-null  int64
#  23  INMUSUPR               996403 non-null  int64
#  24  HIPERTENSION           996403 non-null  int64
#  25  OTRA_COM               996403 non-null  int64
#  26  CARDIOVASCULAR         996403 non-null  int64
#  27  OBESIDAD               996403 non-null  int64
#  28  RENAL_CRONICA          996403 non-null  int64
#  29  TABAQUISMO             996403 non-null  int64
#  30  OTRO_CASO              996403 non-null  int64
#  31  TOMA_MUESTRA_LAB       996403 non-null  int64
#  32  RESULTADO_LAB          996403 non-null  int64
#  33  TOMA_MUESTRA_ANTIGENO  996403 non-null  int64
#  34  RESULTADO_ANTIGENO     996403 non-null  int64
#  35  CLASIFICACION_FINAL    996403 non-null  int64
#  36  MIGRANTE               996403 non-null  int64
#  37  PAIS_NACIONALIDAD      996403 non-null  object
#  38  PAIS_ORIGEN            996403 non-null  object
#  39  UCI                    996403 non-null  int64
# dtypes: int64(33), object(7)
# memory usage: 304.1+ MB

# %% [markdown]
# ## Descripción de las variables
#
# - FECHA_ACTUALIZACION: La base de datos se alimenta diariamente, esta variable permite identificar la fecha de la ultima actualizacion.
# - ID_REGISTRO: Número identificador del caso
# - ORIGEN: La vigilancia centinela se realiza a través del sistema de unidades de salud monitoras de enfermedades respiratorias (USMER). Las USMER incluyen unidades médicas del primer, segundo o tercer nivel de atención y también participan como USMER las unidades de tercer nivel que por sus características contribuyen a ampliar el panorama de información epidemiológica, entre ellas las que cuenten con especialidad de neumología, infectología o pediatría. (Categorías en Catalógo Anexo).
# - SECTOR: Identifica el tipo de institución del Sistema Nacional de Salud que brindó la atención.
# - ENTIDAD_UM: Identifica la entidad donde se ubica la unidad medica que brindó la atención.
# - SEXO: Identifica al sexo del paciente.
# - ENTIDAD_NAC: Identifica la entidad de nacimiento del paciente.
# - ENTIDAD_RES: Identifica la entidad de residencia del paciente.
# - MUNICIPIO_RES: Identifica el municipio de residencia del paciente.
# - TIPO_PACIENTE: Identifica el tipo de atención que recibió el paciente en la unidad. Se denomina como ambulatorio si regresó a su casa o se denomina como hospitalizado si fue ingresado a hospitalización.
# - FECHA_INGRESO: Identifica la fecha de ingreso del paciente a la unidad de atención.
# - FECHA_SINTOMAS: Idenitifica la fecha en que inició la sintomatología del paciente.
# - FECHA_DEF: Identifica la fecha en que el paciente falleció.INTUBADO: Identifica si el paciente requirió de intubación.NEUMONIA: Identifica si al paciente se le diagnosticó con neumonía.
# - EDAD: Identifica la edad del paciente.
# - NACIONALIDAD: Identifica si el paciente es mexicano o extranjero.
# - EMBARAZO: Identifica si la paciente está embarazada.
# - HABLA_LENGUA_INDIG: Identifica si el paciente habla lengua índigena.
# - INDIGENA: Identifica si el paciente se autoidentifica como una persona indígena.
# - DIABETES: Identifica si el paciente tiene un diagnóstico de diabetes.
# - EPOC: Identifica si el paciente tiene un diagnóstico de EPOC.
# - ASMA: Identifica si el paciente tiene un diagnóstico de asma.
# - INMUSUPR: Identifica si el paciente presenta inmunosupresión.
# - HIPERTENSION: Identifica si el paciente tiene un diagnóstico de hipertensión.
# - OTRAS_COM: Identifica si el paciente tiene diagnóstico de otras enfermedades.
# - CARDIOVASCULAR: Identifica si el paciente tiene un diagnóstico de enfermedades cardiovasculares.
# - OBESIDAD: Identifica si el paciente tiene diagnóstico de obesidad.
# - RENAL_CRONICA: Identifica si el paciente tiene diagnóstico de insuficiencia renal crónica.
# - TABAQUISMO: Identifica si el paciente tiene hábito de tabaquismo.
# - OTRO_CASO: Identifica si el paciente tuvo contacto con algún otro caso diagnósticado con SARS CoV-2
# - TOMA_MUESTRA_LAB: Identifica si al paciente se le tomó muestra de laboratorio.
# - RESULTADO_LAB: Identifica el resultado del análisis de la muestra reportado por el  laboratorio de la Red Nacional de Laboratorios de Vigilancia Epidemiológica (INDRE, LESP y LAVE) y laboratorios privados avalados por el InDRE cuyos resultados son registrados en SISVER. (Catálogo de resultados diagnósticos anexo).
# - TOMA_MUESTRA_ANTIGENO: Identifica si al paciente se le tomó muestra de antígeno para SARS-CoV-2
# - RESULTADO_ANTIGENO: Identifica el resultado del análisis de la muestra de antígeno tomada al paciente
# - CLASIFICACION_FINAL: Identifica si el paciente es un caso de COVID-19 según el catálogo "CLASIFICACION_FINAL".
# - MIGRANTE: Identifica si el paciente es una persona migrante.
# - PAIS_NACIONALIDAD: Identifica la nacionalidad del paciente.
# - PAIS_ORIGEN: Identifica el país del que partió el paciente rumbo a México.
# - UCI: Identifica si el paciente requirió ingresar a una Unidad de Cuidados Intensivos.

# %%
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2023-07-25      0ed066       2      12          16     2
# 1          2023-07-25      c4ec68       2      12           9     1
# 2          2023-07-25      b6d4ff       2      12           9     1
# 3          2023-07-25      c92b92       1      12           7     2
# 4          2023-07-25      db9c89       2      12           7     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 0           16           16             41              1  ...         2
# 1            4            9              9              1  ...         2
# 2            9            9              9              1  ...         2
# 3            7            7            101              1  ...         2
# 4            7            7            108              1  ...         2
#
#   TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 0                2            97                      1                   2
# 1                2            97                      1                   2
# 2                2            97                      1                   2
# 3                2            97                      2                  97
# 4                2            97                      2                  97
#
#    CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0                    7        99             México           97   97
# 1                    7        99             México           97   97
# 2                    7        99             México           97   97
# 3                    6        99             México           97   97
# 4                    6        99             México           97   97
#
# [5 rows x 40 columns]

# %%
df['SECTOR'].count()
# Out:
# 996403

# %%
df.groupby(['SECTOR']).count()
# Out:
#         FECHA_ACTUALIZACION  ID_REGISTRO  ORIGEN  ENTIDAD_UM    SEXO  \
# SECTOR
# 1                        15           15      15          15      15
# 2                       236          236     236         236     236
# 3                     13906        13906   13906       13906   13906
# 4                    548199       548199  548199      548199  548199
# 5                      2339         2339    2339        2339    2339
# 6                     47260        47260   47260       47260   47260
# 7                       649          649     649         649     649
# 8                      2465         2465    2465        2465    2465
# 9                     74325        74325   74325       74325   74325
# 10                      275          275     275         275     275
# 11                      321          321     321         321     321
# 12                   305162       305162  305162      305162  305162
# 13                     1109         1109    1109        1109    1109
# 99                      142          142     142         142     142
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  FECHA_INGRESO  \
# SECTOR
# 1                15           15             15             15             15
# 2               236          236            236            236            236
# 3             13906        13906          13906          13906          13906
# 4            548199       548199         548199         548199         548199
# 5              2339         2339           2339           2339           2339
# 6             47260        47260          47260          47260          47260
# 7               649          649            649            649            649
# 8              2465         2465           2465           2465           2465
# 9             74325        74325          74325          74325          74325
# 10              275          275            275            275            275
# 11              321          321            321            321            321
# 12           305162       305162         305162         305162         305162
# 13             1109         1109           1109           1109           1109
# 99              142          142            142            142            142
#
#         ...  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# SECTOR  ...
# 1       ...         15                15             15
# 2       ...        236               236            236
# 3       ...      13906             13906          13906
# 4       ...     548199            548199         548199
# 5       ...       2339              2339           2339
# 6       ...      47260             47260          47260
# 7       ...        649               649            649
# 8       ...       2465              2465           2465
# 9       ...      74325             74325          74325
# 10      ...        275               275            275
# 11      ...        321               321            321
# 12      ...     305162            305162         305162
# 13      ...       1109              1109           1109
# 99      ...        142               142            142
#
#         TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  CLASIFICACION_FINAL  \
# SECTOR
# 1                          15                  15                   15
# 2                         236                 236                  236
# 3                       13906               13906                13906
# 4                      548199              548199               548199
# 5                        2339                2339                 2339
# 6                       47260               47260                47260
# 7                         649                 649                  649
# 8                        2465                2465                 2465
# 9                       74325               74325                74325
# 10                        275                 275                  275
# 11                        321                 321                  321
# 12                     305162              305162               305162
# 13                       1109                1109                 1109
# 99                        142                 142                  142
#
#         MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN     UCI
# SECTOR
# 1             15                 15           15      15
# 2            236                236          236     236
# 3          13906              13906        13906   13906
# 4         548199             548199       548199  548199
# 5           2339               2339         2339    2339
# 6          47260              47260        47260   47260
# 7            649                649          649     649
# 8           2465               2465         2465    2465
# 9          74325              74325        74325   74325
# 10           275                275          275     275
# 11           321                321          321     321
# 12        305162             305162       305162  305162
# 13          1109               1109         1109    1109
# 99           142                142          142     142
#
# [14 rows x 39 columns]

# %%
df.groupby(['SECTOR'])['SECTOR'].count()
# Out:
# SECTOR
# 1         15
# 2        236
# 3      13906
# 4     548199
# 5       2339
# 6      47260
# 7        649
# 8       2465
# 9      74325
# 10       275
# 11       321
# 12    305162
# 13      1109
# 99       142
# Name: SECTOR, dtype: int64

# %%
sector_dict = {1: 'CRUZ ROJA', 2: 'DIF', 3: 'ESTATAL', 4: 'IMSS', 5: 'IMSS-BIENESTAR',
               6: 'ISSSTE', 7: 'MUNICIPAL', 8: 'PEMEX', 9: 'PRIVADA', 10: 'SEDENA',
               11: 'SEMAR', 12: 'SSA', 13: 'UNIVERSITARIO', 99: 'NO ESPECIFICADO'}

# %%
df = df.replace({'SECTOR': sector_dict})

# %%
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN SECTOR  ENTIDAD_UM  SEXO  \
# 0          2023-07-25      0ed066       2    SSA          16     2
# 1          2023-07-25      c4ec68       2    SSA           9     1
# 2          2023-07-25      b6d4ff       2    SSA           9     1
# 3          2023-07-25      c92b92       1    SSA           7     2
# 4          2023-07-25      db9c89       2    SSA           7     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 0           16           16             41              1  ...         2
# 1            4            9              9              1  ...         2
# 2            9            9              9              1  ...         2
# 3            7            7            101              1  ...         2
# 4            7            7            108              1  ...         2
#
#   TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 0                2            97                      1                   2
# 1                2            97                      1                   2
# 2                2            97                      1                   2
# 3                2            97                      2                  97
# 4                2            97                      2                  97
#
#    CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0                    7        99             México           97   97
# 1                    7        99             México           97   97
# 2                    7        99             México           97   97
# 3                    6        99             México           97   97
# 4                    6        99             México           97   97
#
# [5 rows x 40 columns]

# %%
df.groupby('SECTOR').count()
# Out:
#                  FECHA_ACTUALIZACION  ID_REGISTRO  ORIGEN  ENTIDAD_UM    SEXO  \
# SECTOR
# CRUZ ROJA                         15           15      15          15      15
# DIF                              236          236     236         236     236
# ESTATAL                        13906        13906   13906       13906   13906
# IMSS                          548199       548199  548199      548199  548199
# IMSS-BIENESTAR                  2339         2339    2339        2339    2339
# ISSSTE                         47260        47260   47260       47260   47260
# MUNICIPAL                        649          649     649         649     649
# NO ESPECIFICADO                  142          142     142         142     142
# PEMEX                           2465         2465    2465        2465    2465
# PRIVADA                        74325        74325   74325       74325   74325
# SEDENA                           275          275     275         275     275
# SEMAR                            321          321     321         321     321
# SSA                           305162       305162  305162      305162  305162
# UNIVERSITARIO                   1109         1109    1109        1109    1109
#
#                  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# SECTOR
# CRUZ ROJA                 15           15             15             15
# DIF                      236          236            236            236
# ESTATAL                13906        13906          13906          13906
# IMSS                  548199       548199         548199         548199
# IMSS-BIENESTAR          2339         2339           2339           2339
# ISSSTE                 47260        47260          47260          47260
# MUNICIPAL                649          649            649            649
# NO ESPECIFICADO          142          142            142            142
# PEMEX                   2465         2465           2465           2465
# PRIVADA                74325        74325          74325          74325
# SEDENA                   275          275            275            275
# SEMAR                    321          321            321            321
# SSA                   305162       305162         305162         305162
# UNIVERSITARIO           1109         1109           1109           1109
#
#                  FECHA_INGRESO  ...  OTRO_CASO  TOMA_MUESTRA_LAB  \
# SECTOR                          ...
# CRUZ ROJA                   15  ...         15                15
# DIF                        236  ...        236               236
# ESTATAL                  13906  ...      13906             13906
# IMSS                    548199  ...     548199            548199
# IMSS-BIENESTAR            2339  ...       2339              2339
# ISSSTE                   47260  ...      47260             47260
# MUNICIPAL                  649  ...        649               649
# NO ESPECIFICADO            142  ...        142               142
# PEMEX                     2465  ...       2465              2465
# PRIVADA                  74325  ...      74325             74325
# SEDENA                     275  ...        275               275
# SEMAR                      321  ...        321               321
# SSA                     305162  ...     305162            305162
# UNIVERSITARIO             1109  ...       1109              1109
#
#                  RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# SECTOR
# CRUZ ROJA                   15                     15                  15
# DIF                        236                    236                 236
# ESTATAL                  13906                  13906               13906
# IMSS                    548199                 548199              548199
# IMSS-BIENESTAR            2339                   2339                2339
# ISSSTE                   47260                  47260               47260
# MUNICIPAL                  649                    649                 649
# NO ESPECIFICADO            142                    142                 142
# PEMEX                     2465                   2465                2465
# PRIVADA                  74325                  74325               74325
# SEDENA                     275                    275                 275
# SEMAR                      321                    321                 321
# SSA                     305162                 305162              305162
# UNIVERSITARIO             1109                   1109                1109
#
#                  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# SECTOR
# CRUZ ROJA                         15        15                 15
# DIF                              236       236                236
# ESTATAL                        13906     13906              13906
# IMSS                          548199    548199             548199
# IMSS-BIENESTAR                  2339      2339               2339
# ISSSTE                         47260     47260              47260
# MUNICIPAL                        649       649                649
# NO ESPECIFICADO                  142       142                142
# PEMEX                           2465      2465               2465
# PRIVADA                        74325     74325              74325
# SEDENA                           275       275                275
# SEMAR                            321       321                321
# SSA                           305162    305162             305162
# UNIVERSITARIO                   1109      1109               1109
#
#                  PAIS_ORIGEN     UCI
# SECTOR
# CRUZ ROJA                 15      15
# DIF                      236     236
# ESTATAL                13906   13906
# IMSS                  548199  548199
# IMSS-BIENESTAR          2339    2339
# ISSSTE                 47260   47260
# MUNICIPAL                649     649
# NO ESPECIFICADO          142     142
# PEMEX                   2465    2465
# PRIVADA                74325   74325
# SEDENA                   275     275
# SEMAR                    321     321
# SSA                   305162  305162
# UNIVERSITARIO           1109    1109
#
# [14 rows x 39 columns]

# %%
df.groupby('SECTOR')['SECTOR'].count()
# Out:
# SECTOR
# CRUZ ROJA              15
# DIF                   236
# ESTATAL             13906
# IMSS               548199
# IMSS-BIENESTAR       2339
# ISSSTE              47260
# MUNICIPAL             649
# NO ESPECIFICADO       142
# PEMEX                2465
# PRIVADA             74325
# SEDENA                275
# SEMAR                 321
# SSA                305162
# UNIVERSITARIO        1109
# Name: SECTOR, dtype: int64

# %%
df.groupby('SEXO')['SEXO'].count()
# Out:
# SEXO
# 1    584315
# 2    412088
# Name: SEXO, dtype: int64

# %%
df.groupby(['SECTOR', 'SEXO'])['SEXO'].count()
# Out:
# SECTOR           SEXO
# CRUZ ROJA        1            6
#                  2            9
# DIF              1          126
#                  2          110
# ESTATAL          1         8519
#                  2         5387
# IMSS             1       318454
#                  2       229745
# IMSS-BIENESTAR   1         1378
#                  2          961
# ISSSTE           1        30426
#                  2        16834
# MUNICIPAL        1          352
#                  2          297
# NO ESPECIFICADO  1           78
#                  2           64
# PEMEX            1         1298
#                  2         1167
# PRIVADA          1        41849
#                  2        32476
# SEDENA           1          140
#                  2          135
# SEMAR            1          190
#                  2          131
# SSA              1       180853
#                  2       124309
# UNIVERSITARIO    1          646
#                  2          463
# Name: SEXO, dtype: int64

# %%
df.groupby(['SECTOR', 'SEXO'])[['SEXO']].count()
# Out:
#                         SEXO
# SECTOR          SEXO
# CRUZ ROJA       1          6
#                 2          9
# DIF             1        126
#                 2        110
# ESTATAL         1       8519
#                 2       5387
# IMSS            1     318454
#                 2     229745
# IMSS-BIENESTAR  1       1378
#                 2        961
# ISSSTE          1      30426
#                 2      16834
# MUNICIPAL       1        352
#                 2        297
# NO ESPECIFICADO 1         78
#                 2         64
# PEMEX           1       1298
#                 2       1167
# PRIVADA         1      41849
#                 2      32476
# SEDENA          1        140
#                 2        135
# SEMAR           1        190
#                 2        131
# SSA             1     180853
#                 2     124309
# UNIVERSITARIO   1        646
#                 2        463

# %%
# Promedio de edad
df['EDAD'].mean()
# Out:
# 38.39057590151776

# %%
df['EDAD'].describe()
# Out:
# count    996403.000000
# mean         38.390576
# std          19.501438
# min           0.000000
# 25%          25.000000
# 50%          37.000000
# 75%          52.000000
# max         154.000000
# Name: EDAD, dtype: float64

# %%
import seaborn as sns

# %%
sns.histplot(df['EDAD'])
# Out:
# <Axes: xlabel='EDAD', ylabel='Count'>

# %%
sns.histplot(df['EDAD'], bins = 20)
# Out:
# <Axes: xlabel='EDAD', ylabel='Count'>

# %% [markdown]
# # Obteniendo año y mes

# %%
df['FECHA_ACTUALIZACION'].head()
# Out:
# 0    2023-07-25
# 1    2023-07-25
# 2    2023-07-25
# 3    2023-07-25
# 4    2023-07-25
# Name: FECHA_ACTUALIZACION, dtype: object

# %%
df['FECHA_ACTUALIZACION'].str.split('-').head()
# Out:
# 0    [2023, 07, 25]
# 1    [2023, 07, 25]
# 2    [2023, 07, 25]
# 3    [2023, 07, 25]
# 4    [2023, 07, 25]
# Name: FECHA_ACTUALIZACION, dtype: object

# %%
df['FECHA_ACTUALIZACION'].str.split('-').str.len().head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: FECHA_ACTUALIZACION, dtype: int64

# %%
df['FECHA_ACTUALIZACION'].str.split('-').str[0].head()
# Out:
# 0    2023
# 1    2023
# 2    2023
# 3    2023
# 4    2023
# Name: FECHA_ACTUALIZACION, dtype: object

# %%
df['FECHA_ACTUALIZACION'].str.split('-').str[1].head()
# Out:
# 0    07
# 1    07
# 2    07
# 3    07
# 4    07
# Name: FECHA_ACTUALIZACION, dtype: object

# %%
df['FECHA_ACTUALIZACION'].str.split('-').str[2].head()
# Out:
# 0    25
# 1    25
# 2    25
# 3    25
# 4    25
# Name: FECHA_ACTUALIZACION, dtype: object

# %%
df['anio'] = df['FECHA_ACTUALIZACION'].str.split('-').str[0]
df['mes'] = df['FECHA_ACTUALIZACION'].str.split('-').str[1]
df['dia'] = df['FECHA_ACTUALIZACION'].str.split('-').str[2]

# %%
df.groupby('anio')['anio'].count()
# Out:
# anio
# 2023    996403
# Name: anio, dtype: int64

# %%
df.groupby('mes')['mes'].count()
# Out:
# mes
# 07    996403
# Name: mes, dtype: int64

# %%
df.groupby('dia')['dia'].count()
# Out:
# dia
# 25    996403
# Name: dia, dtype: int64

# %%
df["SECTOR"]
# Out:
# 0             SSA
# 1             SSA
# 2             SSA
# 3             SSA
# 4             SSA
#            ...
# 996398        SSA
# 996399        SSA
# 996400    ESTATAL
# 996401        SSA
# 996402        SSA
# Name: SECTOR, Length: 996403, dtype: object

# %%
df.groupby("SECTOR")["SECTOR"].count()
# Out:
# SECTOR
# CRUZ ROJA              15
# DIF                   236
# ESTATAL             13906
# IMSS               548199
# IMSS-BIENESTAR       2339
# ISSSTE              47260
# MUNICIPAL             649
# NO ESPECIFICADO       142
# PEMEX                2465
# PRIVADA             74325
# SEDENA                275
# SEMAR                 321
# SSA                305162
# UNIVERSITARIO        1109
# Name: SECTOR, dtype: int64
